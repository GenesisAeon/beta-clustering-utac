# %% [markdown]
# # β-Distribution across 78 Threshold Systems
#
# Package 32 — beta-clustering-utac (GenesisAeon)
# DOI: 10.5281/zenodo.17472834

# %%
from beta_clustering import BetaClusteringUTAC

system = BetaClusteringUTAC()
result = system.run_cycle()
print(f'Systems: {result["n_systems"]}')
print(f'Inter-cluster ratio: {result["inter_cluster_ratio"]:.5f}')
print(f'Φ^(1/3): {result["phi_cuberoot"]:.5f}')
print(f'Universality rejected: {result["universality_rejected"]}')
